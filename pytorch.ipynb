# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import numpy as np
import time
# %matplotlib inline

# %%
def imshow(img):
    img = img / 2 + 0.5 # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))

# %%
transform=transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                             ])
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, 
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4, 
                                          shuffle=False, num_workers=2)
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [9], line 4
#       1 transform=transforms.Compose([transforms.ToTensor(),
#       2                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
#       3                              ])
# ----> 4 trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=False, transform=transform)
#       5 trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
#       6                                           shuffle=True, num_workers=2)
#       8 testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
#
# File d:\0Programs\Anaconda3\envs\pytorch\lib\site-packages\torchvision\datasets\cifar.py:68, in CIFAR10.__init__(self, root, train, transform, target_transform, download)
#      65     self.download()
#      67 if not self._check_integrity():
# ---> 68     raise RuntimeError("Dataset not found or corrupted. You can use download=True to download it")
#      70 if self.train:
#      71     downloaded_list = self.train_list
#
# RuntimeError: Dataset not found or corrupted. You can use download=True to download it

# %%
# show some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s'%classes[labels[j]] for j in range(4)))
# Out:
#   car   car   car horse

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool  = nn.MaxPool2d(2,2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1   = nn.Linear(16*5*5, 120)
        self.fc2   = nn.Linear(120, 84)
        self.fc3   = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16*5*5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

net = Net()

# %%
criterion = nn.CrossEntropyLoss() # use a Classification Cross-Entropy loss
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
all_begin = time.time()
for epoch in range(5): # loop over the dataset multiple times
    time_begin = time.time()
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        # wrap them in Variable
        inputs, labels = Variable(inputs), Variable(labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999: # print every 2000 mini-batches
            time_end = time.time()
            print('[%d, %5d] loss: %.4f | tt: %.2f' % (epoch+1, i+1, running_loss / 2000, time_end - time_begin))
            if running_loss <= 0.65:
                break
            running_loss = 0.0

print('Finished Training')
print('Total time: %dmin %.1fs' % ((time.time()-all_begin) // 60, (time.time()-all_begin) % 60))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 5
#       3 time_begin = time.time()
#       4 running_loss = 0.0
# ----> 5 for i, data in enumerate(trainloader, 0):
#       6     # get the inputs
#       7     inputs, labels = data
#       9     # wrap them in Variable
#
# NameError: name 'trainloader' is not defined

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()
images, labels = dataiter.next()
# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s'%classes[labels[j]] for j in range(4)))
# Out:
# GroundTruth:   frog  frog   car  frog

# %%
outputs = net(Variable(images))

# the outputs are energies for the 10 classes. 
# Higher the energy for a class, the more the network 
# thinks that the image is of the particular class

# So, let's get the index of the highest energy
_, predicted = torch.max(outputs.data, 1)

print('Predicted: ', ' '.join('%5s'% classes[predicted[j].item()] for j in range(4)))
# Out:
# Predicted:   frog  frog   car  bird

# %%
correct = 0
total = 0
for data in testloader:
    images, labels = data
    outputs = net(Variable(images))
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()

print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 63 %

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
for data in testloader:
    images, labels = data
    outputs = net(Variable(images))
    _, predicted = torch.max(outputs.data, 1)
    c = (predicted == labels).squeeze()
    for i in range(4):
        label = labels[i]
        class_correct[label] += c[i]
        class_total[label] += 1

for i in range(10):
    print('Accuracy of %5s : %2d %%' % (classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of plane : 62 %
# Accuracy of   car : 78 %
# Accuracy of  bird : 57 %
# Accuracy of   cat : 47 %
# Accuracy of  deer : 56 %
# Accuracy of   dog : 53 %
# Accuracy of  frog : 69 %
# Accuracy of horse : 65 %
# Accuracy of  ship : 68 %
# Accuracy of truck : 73 %
